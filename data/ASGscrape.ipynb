# %%
from bs4 import BeautifulSoup
from collections import defaultdict
import pandas as pd
import pickle
import requests
from unidecode import unidecode

# this dictionary will map players to a set containing all the years in which they were selected for an all-star game, either initially or as a replacement
all_star_appearances = defaultdict(set)

# rows to ignore when iterating the roster tables
ignore_fields = set(['Team Totals', 'Reserves'])

START_YEAR, END_YEAR = 1970, 2022

 # unidecode doesn't catch the accented c in Peja's last name (Stojakovic), fix it
 # also overwrite any instance of Metta World Peace to Ron Artest
def fix_name(full_name):
	first_name = full_name.split(' ')[0]
	if first_name == 'Peja':
		return 'Peja Stojakovic'
	elif first_name == 'Metta':
		return 'Ron Artest'
	else:
		return unidecode(full_name)

for year in range(START_YEAR, END_YEAR):

	# no ASG played in 1999 because of the lockout
	if year == 1999:
		continue

	print('Scraping ASG {} data...'.format(year))

	# will store all the all-stars for this year
	all_stars = set([])

	html = requests.get('https://www.basketball-reference.com/allstar/NBA_{}.html'.format(year)).content
	soup = BeautifulSoup(html, 'html.parser')

	# this part was annoying - back when ASG was always East vs. West, the tables were encoded with id="East"/id="West" so they could be extracted more easily/reliably
	# but now, you have games like Giannis vs. LeBron and the table id's are different, so I had to extract them by index, which is unreliable in the event that the 
	# site's design changes in the future

	# gets rosters for team 1 and team 2
	s1, s2 = soup.findAll('table')[1:3]

	df1 = pd.read_html(str(s1))[0]
	df2 = pd.read_html(str(s2))[0]

	# get the all-stars from teams 1 and 2
	for df in [df1, df2]:
		for i, row in df.iterrows():
			if pd.notnull(row[0]) and row[0] not in ignore_fields:
				player = row[0]
				all_stars.add(fix_name(player))

	# gets all li elements in the page
	s3 = soup.findAll('li') 

	# finds the li element that contains the data pertaining to injury related selections - players who were selected but couldn't participate due to injury,
	# and their respective replacements
	#
	# since all_stars is a hashset, we don't need to worry about accidentally double counting an all-star
	for s in s3:
		if 'Did not play' in str(s):
			for player in [name.get_text() for name in s.findAll('a')]: # all the injured players and their replacements
				all_stars.add(fix_name(player))
			break

	# update the appearances dictionary
	for player in all_stars:
		all_star_appearances[player].add(year)

sorted_all_star_appearances = sorted([(player, sorted(list(appearances))) for player, appearances in all_star_appearances.items()], key = lambda x : -len(x[1]))

print('\nAll all-star appearances since 1970 (sorted by number of appearances):\n')

for player, appearances in sorted_all_star_appearances:
	print('{}: {}'.format(player, appearances))

# export the dictionary to local disk for future recall in statsnba_fullscrape.py
out = open('all_star_appearances.pickle', 'wb')
pickle.dump(all_star_appearances, out)
out.close
# Out:
# Scraping ASG 1970 data...
# Scraping ASG 1971 data...
# Scraping ASG 1972 data...
# Scraping ASG 1973 data...
# Scraping ASG 1974 data...
# Scraping ASG 1975 data...
# Scraping ASG 1976 data...
# Scraping ASG 1977 data...
# Scraping ASG 1978 data...
# Scraping ASG 1979 data...
# Scraping ASG 1980 data...
# Scraping ASG 1981 data...
# Scraping ASG 1982 data...
# Scraping ASG 1983 data...
# Scraping ASG 1984 data...
# Scraping ASG 1985 data...
# Scraping ASG 1986 data...
# Scraping ASG 1987 data...
# Scraping ASG 1988 data...
# Scraping ASG 1989 data...
# Scraping ASG 1990 data...
# Scraping ASG 1991 data...
# Scraping ASG 1992 data...
# Scraping ASG 1993 data...
# Scraping ASG 1994 data...
# Scraping ASG 1995 data...
# Scraping ASG 1996 data...
# Scraping ASG 1997 data...
# Scraping ASG 1998 data...
# Scraping ASG 2000 data...
# Scraping ASG 2001 data...
# Scraping ASG 2002 data...
# Scraping ASG 2003 data...
# Scraping ASG 2004 data...
# Scraping ASG 2005 data...
# Scraping ASG 2006 data...
# Scraping ASG 2007 data...
# Scraping ASG 2008 data...
# Scraping ASG 2009 data...
# Scraping ASG 2010 data...
# Scraping ASG 2011 data...
# Scraping ASG 2012 data...
# Scraping ASG 2013 data...
# Scraping ASG 2014 data...
# Scraping ASG 2015 data...
# Scraping ASG 2016 data...
# Scraping ASG 2017 data...
# Scraping ASG 2018 data...
# Scraping ASG 2019 data...
# Scraping ASG 2020 data...
# Scraping ASG 2021 data...
#
# All all-star appearances since 1970 (sorted by number of appearances):
#
# Kareem Abdul-Jabbar: [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989]
# Kobe Bryant: [1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# LeBron James: [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Shaquille O'Neal: [1993, 1994, 1995, 1996, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2009]
# Kevin Garnett: [1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2013]
# Tim Duncan: [1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2013, 2015]
# Michael Jordan: [1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1996, 1997, 1998, 2002, 2003]
# Karl Malone: [1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 2000, 2001, 2002]
# Dirk Nowitzki: [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2015, 2019]
# Dwyane Wade: [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2019]
# Moses Malone: [1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989]
# Larry Bird: [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1990, 1991, 1992]
# Magic Johnson: [1980, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992]
# Isiah Thomas: [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993]
# Hakeem Olajuwon: [1985, 1986, 1987, 1988, 1989, 1990, 1992, 1993, 1994, 1995, 1996, 1997]
# Elvin Hayes: [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980]
# Julius Erving: [1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987]
# Patrick Ewing: [1986, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997]
# Charles Barkley: [1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997]
# Allen Iverson: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
# Chris Bosh: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# Chris Paul: [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2020, 2021]
# Kevin Durant: [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2021]
# Clyde Drexler: [1986, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996, 1997]
# John Stockton: [1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 2000]
# David Robinson: [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1998, 2000, 2001]
# Jason Kidd: [1996, 1998, 2000, 2001, 2002, 2003, 2004, 2007, 2008, 2010]
# Ray Allen: [2000, 2001, 2002, 2004, 2005, 2006, 2007, 2008, 2009, 2011]
# Paul Pierce: [2002, 2003, 2004, 2005, 2006, 2008, 2009, 2010, 2011, 2012]
# Carmelo Anthony: [2007, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
# John Havlicek: [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978]
# George Gervin: [1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985]
# Robert Parish: [1981, 1982, 1983, 1984, 1985, 1986, 1987, 1990, 1991]
# Dominique Wilkins: [1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994]
# Gary Payton: [1994, 1995, 1996, 1997, 1998, 2000, 2001, 2002, 2003]
# Russell Westbrook: [2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020]
# James Harden: [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Dave Cowens: [1972, 1973, 1974, 1975, 1976, 1977, 1978, 1980]
# Bob Lanier: [1972, 1973, 1974, 1975, 1977, 1978, 1979, 1982]
# Alex English: [1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989]
# Dikembe Mutombo: [1992, 1995, 1996, 1997, 1998, 2000, 2001, 2002]
# Vince Carter: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Steve Nash: [2002, 2003, 2005, 2006, 2007, 2008, 2010, 2012]
# Yao Ming: [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2011]
# Dwight Howard: [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
# Anthony Davis: [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Walt Frazier: [1970, 1971, 1972, 1973, 1974, 1975, 1976]
# Jo Jo White: [1971, 1972, 1973, 1974, 1975, 1976, 1977]
# Jack Sikma: [1979, 1980, 1981, 1982, 1983, 1984, 1985]
# Kevin McHale: [1984, 1986, 1987, 1988, 1989, 1990, 1991]
# James Worthy: [1986, 1987, 1988, 1989, 1990, 1991, 1992]
# Scottie Pippen: [1990, 1992, 1993, 1994, 1995, 1996, 1997]
# Alonzo Mourning: [1994, 1995, 1996, 1997, 2000, 2001, 2002]
# Grant Hill: [1995, 1996, 1997, 1998, 2000, 2001, 2005]
# Tracy McGrady: [2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Joe Johnson: [2007, 2008, 2009, 2010, 2011, 2012, 2014]
# LaMarcus Aldridge: [2012, 2013, 2014, 2015, 2016, 2018, 2019]
# Paul George: [2013, 2014, 2016, 2017, 2018, 2019, 2021]
# Kyrie Irving: [2013, 2014, 2015, 2017, 2018, 2019, 2021]
# Stephen Curry: [2014, 2015, 2016, 2017, 2018, 2019, 2021]
# Tiny Archibald: [1973, 1975, 1976, 1980, 1981, 1982]
# Rick Barry: [1973, 1974, 1975, 1976, 1977, 1978]
# Artis Gilmore: [1978, 1979, 1981, 1982, 1983, 1986]
# Walter Davis: [1978, 1979, 1980, 1981, 1984, 1987]
# Adrian Dantley: [1980, 1981, 1982, 1984, 1985, 1986]
# Joe Dumars: [1990, 1991, 1992, 1993, 1995, 1997]
# Mitch Richmond: [1993, 1994, 1995, 1996, 1997, 1998]
# Shawn Kemp: [1993, 1994, 1995, 1996, 1997, 1998]
# Jermaine O'Neal: [2002, 2003, 2004, 2005, 2006, 2007]
# Amar'e Stoudemire: [2005, 2007, 2008, 2009, 2010, 2011]
# Pau Gasol: [2006, 2009, 2010, 2011, 2015, 2016]
# Tony Parker: [2006, 2007, 2009, 2012, 2013, 2014]
# Blake Griffin: [2011, 2012, 2013, 2014, 2015, 2019]
# Damian Lillard: [2014, 2015, 2018, 2019, 2020, 2021]
# Kyle Lowry: [2015, 2016, 2017, 2018, 2019, 2020]
# Dave DeBusschere: [1970, 1971, 1972, 1973, 1974]
# Jerry West: [1970, 1971, 1972, 1973, 1974]
# Lou Hudson: [1970, 1971, 1972, 1973, 1974]
# Dave Bing: [1971, 1973, 1974, 1975, 1976]
# Pete Maravich: [1973, 1974, 1977, 1978, 1979]
# Rudy Tomjanovich: [1974, 1975, 1976, 1977, 1979]
# Bob McAdoo: [1974, 1975, 1976, 1977, 1978]
# Paul Westphal: [1977, 1978, 1979, 1980, 1981]
# Dennis Johnson: [1979, 1980, 1981, 1982, 1985]
# Marques Johnson: [1979, 1980, 1981, 1983, 1986]
# Sidney Moncrief: [1982, 1983, 1984, 1985, 1986]
# Brad Daugherty: [1988, 1989, 1991, 1992, 1993]
# Chris Mullin: [1989, 1990, 1991, 1992, 1993]
# Reggie Miller: [1990, 1995, 1996, 1998, 2000]
# Tim Hardaway: [1991, 1992, 1993, 1997, 1998]
# Chris Webber: [1997, 2000, 2001, 2002, 2003]
# Chauncey Billups: [2006, 2007, 2008, 2009, 2010]
# Al Horford: [2010, 2011, 2015, 2016, 2018]
# Kevin Love: [2011, 2012, 2014, 2017, 2018]
# John Wall: [2014, 2015, 2016, 2017, 2018]
# Jimmy Butler: [2015, 2016, 2017, 2018, 2020]
# Klay Thompson: [2015, 2016, 2017, 2018, 2019]
# Kawhi Leonard: [2016, 2017, 2019, 2020, 2021]
# Giannis Antetokounmpo: [2017, 2018, 2019, 2020, 2021]
# Connie Hawkins: [1970, 1971, 1972, 1973]
# Chet Walker: [1970, 1971, 1973, 1974]
# Wes Unseld: [1971, 1972, 1973, 1975]
# Gail Goodrich: [1972, 1973, 1974, 1975]
# Sidney Wicks: [1972, 1973, 1974, 1975]
# Spencer Haywood: [1972, 1973, 1974, 1975]
# Bob Dandridge: [1973, 1975, 1976, 1979]
# Doug Collins: [1976, 1977, 1978, 1979]
# David Thompson: [1977, 1978, 1979, 1983]
# Bobby Jones: [1977, 1978, 1981, 1982]
# Maurice Lucas: [1977, 1978, 1979, 1983]
# Otis Birdsong: [1979, 1980, 1981, 1984]
# Micheal Ray Richardson: [1980, 1981, 1982, 1985]
# Bernard King: [1982, 1984, 1985, 1991]
# Bill Laimbeer: [1983, 1984, 1985, 1987]
# Maurice Cheeks: [1983, 1986, 1987, 1988]
# Ralph Sampson: [1984, 1985, 1986, 1987]
# Rolando Blackman: [1985, 1986, 1987, 1990]
# Alvin Robertson: [1986, 1987, 1988, 1991]
# Tom Chambers: [1987, 1989, 1990, 1991]
# Mark Price: [1989, 1992, 1993, 1994]
# Latrell Sprewell: [1994, 1995, 1997, 2001]
# Vin Baker: [1995, 1996, 1997, 1998]
# Anfernee Hardaway: [1995, 1996, 1997, 1998]
# Rasheed Wallace: [2000, 2001, 2006, 2008]
# Ben Wallace: [2003, 2004, 2005, 2006]
# Shawn Marion: [2003, 2005, 2006, 2007]
# Rajon Rondo: [2010, 2011, 2012, 2013]
# DeMar DeRozan: [2014, 2016, 2017, 2018]
# Paul Millsap: [2014, 2015, 2016, 2017]
# DeMarcus Cousins: [2015, 2016, 2017, 2018]
# Kemba Walker: [2017, 2018, 2019, 2020]
# Joel Embiid: [2018, 2019, 2020, 2021]
# Lenny Wilkens: [1970, 1971, 1973]
# Oscar Robertson: [1970, 1971, 1972]
# Tom Van Arsdale: [1970, 1971, 1972]
# Billy Cunningham: [1970, 1971, 1972]
# Nate Thurmond: [1970, 1973, 1974]
# Wilt Chamberlain: [1971, 1972, 1973]
# Bob Kauffman: [1971, 1972, 1973]
# Earl Monroe: [1971, 1975, 1977]
# Bob Love: [1971, 1972, 1973]
# Charlie Scott: [1973, 1974, 1975]
# Phil Chenier: [1974, 1975, 1977]
# Norm Van Lier: [1974, 1976, 1977]
# George McGinnis: [1976, 1977, 1979]
# Jamaal Wilkes: [1976, 1981, 1983]
# Dan Roundfield: [1980, 1981, 1982]
# Buck Williams: [1982, 1983, 1986]
# Mark Aguirre: [1984, 1987, 1988]
# Larry Nance: [1985, 1989, 1993]
# Kevin Johnson: [1990, 1991, 1994]
# Dan Majerle: [1992, 1993, 1995]
# Detlef Schrempf: [1993, 1995, 1997]
# Glen Rice: [1996, 1997, 1998]
# Eddie Jones: [1997, 1998, 2000]
# Antoine Walker: [1998, 2002, 2003]
# Steve Francis: [2002, 2003, 2004]
# Peja Stojakovic: [2002, 2003, 2004]
# Gilbert Arenas: [2005, 2006, 2007]
# Richard Hamilton: [2006, 2007, 2008]
# Brandon Roy: [2008, 2009, 2010]
# Deron Williams: [2010, 2011, 2012]
# Derrick Rose: [2010, 2011, 2012]
# Marc Gasol: [2012, 2015, 2017]
# Draymond Green: [2016, 2017, 2018]
# Bradley Beal: [2018, 2019, 2021]
# Ben Simmons: [2019, 2020, 2021]
# Nikola Jokic: [2019, 2020, 2021]
# Dick Van Arsdale: [1970, 1971]
# Gus Johnson: [1970, 1971]
# Jimmy Walker: [1970, 1972]
# Willis Reed: [1970, 1971]
# Jeff Mullins: [1970, 1971]
# John Johnson: [1971, 1972]
# Geoff Petrie: [1971, 1974]
# Paul Silas: [1972, 1975]
# Jack Marin: [1972, 1973]
# Randy Smith: [1976, 1978]
# Phil Smith: [1976, 1977]
# John Drew: [1976, 1980]
# Scott Wedman: [1976, 1980]
# Brian Winters: [1976, 1978]
# Bill Walton: [1977, 1978]
# Billy Knight: [1977, 1978]
# Larry Kenon: [1978, 1979]
# Truck Robinson: [1978, 1981]
# Eddie Johnson: [1980, 1981]
# Reggie Theus: [1981, 1983]
# Gus Williams: [1982, 1983]
# Norm Nixon: [1982, 1985]
# Kelly Tripucka: [1982, 1984]
# Andrew Toney: [1983, 1984]
# Kiki Vandeweghe: [1983, 1984]
# Jim Paxson: [1983, 1984]
# Jeff Ruland: [1984, 1985]
# Terry Cummings: [1985, 1989]
# Jeff Malone: [1986, 1987]
# Fat Lever: [1988, 1990]
# Kevin Duckworth: [1989, 1991]
# Dennis Rodman: [1990, 1992]
# Terry Porter: [1991, 1993]
# Sean Elliott: [1993, 1996]
# Danny Manning: [1993, 1994]
# Larry Johnson: [1993, 1995]
# Terrell Brandon: [1996, 1997]
# Allan Houston: [2000, 2001]
# Glenn Robinson: [2000, 2001]
# Michael Finley: [2000, 2001]
# Jerry Stackhouse: [2000, 2001]
# Stephon Marbury: [2001, 2003]
# Baron Davis: [2002, 2004]
# Elton Brand: [2002, 2006]
# Brad Miller: [2003, 2004]
# Zydrunas Ilgauskas: [2003, 2005]
# Rashard Lewis: [2005, 2009]
# Manu Ginobili: [2005, 2011]
# Antawn Jamison: [2005, 2008]
# Carlos Boozer: [2007, 2008]
# Caron Butler: [2007, 2008]
# David West: [2008, 2009]
# David Lee: [2010, 2013]
# Zach Randolph: [2010, 2013]
# Luol Deng: [2012, 2013]
# Roy Hibbert: [2012, 2014]
# Joakim Noah: [2013, 2014]
# Isaiah Thomas: [2016, 2017]
# Andre Drummond: [2016, 2018]
# Karl-Anthony Towns: [2018, 2019]
# Victor Oladipo: [2018, 2019]
# Khris Middleton: [2019, 2020]
# Nikola Vucevic: [2019, 2021]
# Domantas Sabonis: [2020, 2021]
# Jayson Tatum: [2020, 2021]
# Donovan Mitchell: [2020, 2021]
# Devin Booker: [2020, 2021]
# Rudy Gobert: [2020, 2021]
# Luka Doncic: [2020, 2021]
# Flynn Robinson: [1970]
# Joe Caldwell: [1970]
# Bill Bridges: [1970]
# Hal Greer: [1970]
# Bob Rule: [1970]
# Elgin Baylor: [1970]
# Johnny Green: [1971]
# Jerry Lucas: [1971]
# Archie Clark: [1972]
# Cazzie Russell: [1972]
# Butch Beard: [1972]
# Bill Bradley: [1973]
# John Block: [1973]
# Austin Carr: [1974]
# Sam Lacey: [1975]
# Jim Price: [1975]
# Steve Mix: [1975]
# Fred Brown: [1976]
# Curtis Rowe: [1976]
# Alvan Adams: [1976]
# Dan Issel: [1977]
# Don Buse: [1977]
# Lionel Hollins: [1978]
# Campy Russell: [1979]
# Calvin Murphy: [1979]
# Kermit Washington: [1980]
# World B. Free: [1980]
# Bill Cartwright: [1980]
# Mike Mitchell: [1981]
# Lonnie Shelton: [1982]
# Rickey Green: [1984]
# Calvin Natt: [1985]
# Joe Barry Carroll: [1987]
# Sleepy Floyd: [1987]
# Xavier McDaniel: [1988]
# Doc Rivers: [1988]
# Steve Johnson: [1988]
# Danny Ainge: [1988]
# James Donaldson: [1988]
# Mark Jackson: [1989]
# Dale Ellis: [1989]
# Mark Eaton: [1989]
# A.C. Green: [1990]
# Ricky Pierce: [1991]
# Hersey Hawkins: [1991]
# Jeff Hornacek: [1992]
# Michael Adams: [1992]
# Kevin Willis: [1992]
# Otis Thorpe: [1992]
# Reggie Lewis: [1992]
# Clifford Robinson: [1994]
# B.J. Armstrong: [1994]
# Mookie Blaylock: [1994]
# Derrick Coleman: [1994]
# Kenny Anderson: [1994]
# Charles Oakley: [1994]
# John Starks: [1994]
# Horace Grant: [1994]
# Tyrone Hill: [1995]
# Dana Barros: [1995]
# Cedric Ceballos: [1995]
# Juwan Howard: [1996]
# Chris Gatling: [1997]
# Christian Laettner: [1997]
# Tom Gugliotta: [1997]
# Jayson Williams: [1998]
# Nick Van Exel: [1998]
# Steve Smith: [1998]
# Rik Smits: [1998]
# Dale Davis: [2000]
# Theo Ratliff: [2001]
# Vlade Divac: [2001]
# Antonio Davis: [2001]
# Anthony Mason: [2001]
# Antonio McDyess: [2001]
# Shareef Abdur-Rahim: [2002]
# Wally Szczerbiak: [2002]
# Jamal Mashburn: [2003]
# Michael Redd: [2004]
# Andrei Kirilenko: [2004]
# Kenyon Martin: [2004]
# Jamaal Magloire: [2004]
# Ron Artest: [2004]
# Sam Cassell: [2004]
# Josh Howard: [2007]
# Mehmet Okur: [2007]
# Devin Harris: [2009]
# Mo Williams: [2009]
# Danny Granger: [2009]
# Jameer Nelson: [2009]
# Gerald Wallace: [2010]
# Chris Kaman: [2010]
# Andre Iguodala: [2012]
# Andrew Bynum: [2012]
# Jrue Holiday: [2013]
# Tyson Chandler: [2013]
# Brook Lopez: [2013]
# Jeff Teague: [2015]
# Kyle Korver: [2015]
# DeAndre Jordan: [2017]
# Gordon Hayward: [2017]
# Kristaps Porzingis: [2018]
# Goran Dragic: [2018]
# D'Angelo Russell: [2019]
# Pascal Siakam: [2020]
# Brandon Ingram: [2020]
# Trae Young: [2020]
# Bam Adebayo: [2020]
# Mike Conley: [2021]
# Zion Williamson: [2021]
# Jaylen Brown: [2021]
# Julius Randle: [2021]
# Zach LaVine: [2021]
# <function BufferedWriter.close>
